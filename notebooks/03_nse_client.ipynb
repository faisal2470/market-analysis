# %%
from market_analysis.data.providers.nse import NSEClient
from market_analysis.database.models.enums import SymbolColumns
import matplotlib.pyplot as plt

# %%
client = NSEClient()

# %%
df = client.fetch_symbols(series=None)

# %%
df.describe()
# Out:
#                      listing_date  paid_up_value   market_lot   face_value
# count                        2389    2389.000000  2389.000000  2389.000000
# mean   2013-12-08 12:34:39.531184       6.411469     1.123901     6.411469
# min           1995-02-08 00:00:00       1.000000     1.000000     1.000000
# 25%           2006-02-15 00:00:00       2.000000     1.000000     2.000000
# 50%           2016-06-14 00:00:00       5.000000     1.000000     5.000000
# 75%           2023-04-25 00:00:00      10.000000     1.000000    10.000000
# max           2026-07-30 00:00:00    1000.000000   100.000000  1000.000000
# std                           NaN      20.737012     3.194381    20.737012
